# %% [markdown]
# <a href="https://colab.research.google.com/github/ashikhaj/PhoneDirectory/blob/main/Copy_of_Copy_of_Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis

# %%
data1=pd.read_csv("educ_inc.csv")
data2=pd.read_csv("nba_salaries.csv")
data3=pd.read_csv("test1.csv")

# %%
data2.describe()
# Out:
#            SALARY
# count  417.000000
# mean     5.074814
# std      5.221437
# min      0.030888
# 25%      1.270964
# 50%      3.000000
# 75%      7.000000
# max     25.000000

# %% [markdown]
# B:QUESTION-4

# %%
df1=data2[data2['SALARY']>=10.00000]
print(df1)
# Out:
#              PLAYER POSITION                TEAM     SALARY
# 0      Paul Millsap       PF       Atlanta Hawks  18.671659
# 1        Al Horford        C       Atlanta Hawks  12.000000
# 29      Joe Johnson       SF       Brooklyn Nets  24.894863
# 30   Thaddeus Young       PF       Brooklyn Nets  11.235955
# 42     Al Jefferson        C   Charlotte Hornets  13.500000
# ..              ...      ...                 ...        ...
# 368   DeMar DeRozan       SG     Toronto Raptors  10.050000
# 383  Gordon Hayward       SF           Utah Jazz  15.409570
# 400       John Wall       PG  Washington Wizards  15.851950
# 401    Nene Hilario        C  Washington Wizards  13.000000
# 402   Marcin Gortat        C  Washington Wizards  11.217391
#
# [70 rows x 4 columns]

# %% [markdown]
# B) question 5

# %%
print(len(data2[data2['TEAM']=='Atlanta Hawks']))
print(len(data2[data2['TEAM']=='Brooklyn Nets']))

print(len(data2[data2['TEAM']=='Charlotte Hornets']))

print(len(data2[data2['TEAM']=='Cleveland Cavaliers']))

print(len(data2[data2['TEAM']=='Dallas Mavericks']))

print(len(data2[data2['TEAM']=='Denver Nuggets']))

print(len(data2[data2['TEAM']=='Detroit Pistons']))

print(len(data2[data2['TEAM']=='Golden State Warriors']))

print(len(data2[data2['TEAM']=='Houston Rockets']))

print(len(data2[data2['TEAM']=='Indiana Pacers']))

print(len(data2[data2['TEAM']=='Los Angeles Lakers']))

print(len(data2[data2['TEAM']=='Memphis Grizzlies']))

print(len(data2[data2['TEAM']=='Milwaukee Bucks']))

print(len(data2[data2['TEAM']=='Minnesota Timberwolves']))

print(len(data2[data2['TEAM']=='New Orleans Pelicans']))

print(len(data2[data2['TEAM']=='New York Knicks']))

print(len(data2[data2['TEAM']=='Oklahoma City Thunder']))

print(len(data2[data2['TEAM']=='Orlando Magic']))

print(len(data2[data2['TEAM']=='Philadelphia 76ers']))

print(len(data2[data2['TEAM']=='Phoenix Suns']))

print(len(data2[data2['TEAM']=='Portland Trail Blazers']))

print(len(data2[data2['TEAM']=='Sacramento Kings']))

print(len(data2[data2['TEAM']=='San Antonio Spurs']))

print(len(data2[data2['TEAM']=='Toronto Raptors']))

print(len(data2[data2['TEAM']=='Utah Jazz']))

print(len(data2[data2['TEAM']=='Washington Wizards']))
# Out:
# 14
# 13
# 18
# 10
# 11
# 14
# 10
# 14
# 12
# 13
# 11
# 21
# 13
# 13
# 16
# 13
# 16
# 14
# 13
# 17
# 14
# 11
# 13
# 17
# 17
# 17

# %% [markdown]
# A) QUESTION1)

# %%
gk =data1.groupby(['Educational Attainment']).sum()
print(gk)
# Out:
#                                 Population Count
# Educational Attainment
# Bachelor's degree or higher             54617676
# College, less than 4-yr degree          52137494
# High school or equivalent               42942926
# No high school diploma                  40668871
# <ipython-input-12-bb7b21054c7d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gk =data1.groupby(['Educational Attainment']).sum()

# %%
data1.describe()
# Out:
#        Population Count
# count      1.026000e+03
# mean       1.855429e+05
# std        2.187005e+05
# min        1.048000e+03
# 25%        3.052250e+04
# 50%        9.039300e+04
# 75%        2.879518e+05
# max        1.643095e+06

# %%
c)question 10

# %%
data3 = data3.dropna(axis=0)
data = data3[d.iloc[:,-6] == "Female"]
average_age_female = data.iloc[:,2].mean()
print(average_age_female)
# Out:
# nan

# %%
data3.describe()
# Out:
#         Unnamed: 0           39         77516           13          2174  \
# count  8540.000000  8540.000000  8.539000e+03  8539.000000   8539.000000
# mean   4269.500000    38.459953  1.904491e+05    10.073311   1053.643869
# std    2465.429983    13.584405  1.064337e+05     2.544385   7265.717097
# min       0.000000    17.000000  1.930200e+04     1.000000      0.000000
# 25%    2134.750000    28.000000  1.179165e+05     9.000000      0.000000
# 50%    4269.500000    37.000000  1.786440e+05    10.000000      0.000000
# 75%    6404.250000    47.000000  2.387995e+05    12.000000      0.000000
# max    8539.000000    90.000000  1.226583e+06    16.000000  99999.000000
#
#                  0           40
# count  8539.000000  8539.000000
# mean     89.770933    40.509779
# std     404.172943    12.265977
# min       0.000000     1.000000
# 25%       0.000000    40.000000
# 50%       0.000000    40.000000
# 75%       0.000000    45.000000
# max    3004.000000    99.000000

# %% [markdown]
# C)
# Question 7

# %%
data3.columns =['Srl No', 'age', 'type_employer', 'fnlwgt','education', 'education_num','marital','occupation','relationship','race','sex','capital_gain','capital_loss','hr_per_week', 'country', 'income']
print(data3)
# Out:
#       Srl No  age      type_employer    fnlwgt      education  education_num  \
# 0          0   50   Self-emp-not-inc   83311.0      Bachelors           13.0
# 1          1   38            Private  215646.0        HS-grad            9.0
# 2          2   53            Private  234721.0           11th            7.0
# 3          3   28            Private  338409.0      Bachelors           13.0
# 4          4   37            Private  284582.0        Masters           14.0
# ...      ...  ...                ...       ...            ...            ...
# 8535    8535   77       Self-emp-inc  192230.0   Some-college           10.0
# 8536    8536   32            Private  292592.0        HS-grad            9.0
# 8537    8537   27            Private  330132.0      Bachelors           13.0
# 8538    8538   22            Private   51111.0   Some-college           10.0
# 8539    8539   35                NaN       NaN            NaN            NaN
#
# ...

# %%
print(data3)
# Out:
#       Srl No  age      type_employer    fnlwgt      education  education_num  \
# 0          0   50   Self-emp-not-inc   83311.0      Bachelors           13.0
# 1          1   38            Private  215646.0        HS-grad            9.0
# 2          2   53            Private  234721.0           11th            7.0
# 3          3   28            Private  338409.0      Bachelors           13.0
# 4          4   37            Private  284582.0        Masters           14.0
# ...      ...  ...                ...       ...            ...            ...
# 8535    8535   77       Self-emp-inc  192230.0   Some-college           10.0
# 8536    8536   32            Private  292592.0        HS-grad            9.0
# 8537    8537   27            Private  330132.0      Bachelors           13.0
# 8538    8538   22            Private   51111.0   Some-college           10.0
# 8539    8539   35                NaN       NaN            NaN            NaN
#
# ...

# %% [markdown]
# c) question 12

# %%
men_data = data3[data3["sex"] == "Male"]
ages_of_men = men_data["age"]
plt.hist(ages_of_men, bins=20, edgecolor='b', alpha=0.7, color='skyblue')
skewness=ages_of_men.skew()
print(skewness)
plt.show()
# Out:
# nan

# %% [markdown]
# C) QUESTION 9

# %%
df=pd.DataFrame(data3)
Age=df["age"]
s=skew(Age)
kur=kurtosis(Age)
print(s)
print(kur)
# Out:
# 0.5750193721365284
# -0.10179741039963375
